# %%
# Instala ultralytics
# %pip install ultralytics
# Importa libreria ultralytics
import ultralytics
# Revisa y visualiza las capacidades computacionales del computador virtual
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from ultralytics import settings

# Update a setting
settings.update({'runs_dir': '/content/drive/MyDrive/Datasets/Dataset1.v4i.yolov8/runs/segment/train'})

# %%
# !yolo task=segment mode=train model=yolov8m-seg.pt data= /content/drive/MyDrive/Datasets/Dataset1.v4i.yolov8/data.yaml epochs=10 imgsz=448 plots=True save_period=1
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename='/content/drive/MyDrive/Datasets/Dataset1.v4i.yolov8/runs/segment/train/segment/train/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/Datasets/Dataset1.v4i.yolov8/runs/segment/train/segment/train/results.png', width=800)

# %%
Image(filename='/content/drive/MyDrive/Datasets/Dataset1.v4i.yolov8/runs/segment/train/segment/train/val_batch0_pred.jpg', width=600)
